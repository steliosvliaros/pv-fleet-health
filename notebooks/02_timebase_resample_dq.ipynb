# %% [markdown]
# 02 – Time Index Audit, Resampling, Early EDA, Data Quality
#
# This notebook:
#
# Loads scada_wide.parquet + signal_catalog.parquet
#
# Wide→Long normalization
#
# Time index audit (duplicates/gaps/median dt)
#
# Resample to standard timebase (e.g., 5min)
#
# Early EDA (missingness, distributions, sanity plots)
#
# DQ scoring + monitoring confidence
#
# Writes Parquet:
#
# outputs/stages/scada_long.parquet
#
# outputs/stages/scada_rs.parquet
#
# outputs/stages/time_audit.parquet
#
# outputs/stages/dq_report.parquet

# %%
from pathlib import Path

import pandas as pd

from pv_fleet_health.config import load_config_yaml
from pv_fleet_health.io import save_parquet
from pv_fleet_health.paths import Paths
from pv_fleet_health.scada_reshape import wide_to_long

ROOT = Path("..").resolve()
paths = Paths(ROOT)
paths.ensure()
cfg = load_config_yaml(str(ROOT / "config.yaml"))

# %%
scada_wide = pd.read_parquet(paths.stage_dir / "scada_wide.parquet")
signal_catalog = pd.read_parquet(paths.stage_dir / "signal_catalog.parquet")

print("Loaded scada_wide:", scada_wide.shape)
print("Loaded signal_catalog:", signal_catalog.shape)

# Optional: debug mode
if cfg.selected_plant is not None:
    keep_cols = [cfg.timestamp_col] + signal_catalog["raw_column_name"].tolist()
    scada_wide = scada_wide[keep_cols].copy()
    print("Filtered debug plant columns:", scada_wide.shape)
# Out:
# Loaded scada_wide: (2400, 244)
# Loaded signal_catalog: (243, 12)

# %%
scada_long = wide_to_long(scada_wide, signal_catalog, cfg.timestamp_col)
print("scada_long:", scada_long.shape)
print(scada_long[["ts", "plant_name", "component_type", "canonical_signal", "value"]].head(5))

save_parquet(scada_long, str(paths.stage_dir / "scada_long.parquet"))
# Out:
# scada_long: (583200, 11)
#                          ts                      plant_name component_type  \
# 0 2025-12-01 00:15:00+02:00  Solar Concept 3721 KWp Lexaina          array
# 1 2025-12-01 00:30:00+02:00  Solar Concept 3721 KWp Lexaina          array
# 2 2025-12-01 00:45:00+02:00  Solar Concept 3721 KWp Lexaina          array
# 3 2025-12-01 01:00:00+02:00  Solar Concept 3721 KWp Lexaina          array
# 4 2025-12-01 01:15:00+02:00  Solar Concept 3721 KWp Lexaina          array
#
#         canonical_signal         value
# 0  ac_frequency_error_hz   -1,88999999
# 1  ac_frequency_error_hz  -0,643333316
# 2  ac_frequency_error_hz   -1,43444443
# 3  ac_frequency_error_hz   0,094444446
# 4  ac_frequency_error_hz   -2,10777783
# ---------------------------------------------------------------------------
# ArrowTypeError                            Traceback (most recent call last)
# Cell In[5], line 5
#       2 print("scada_long:", scada_long.shape)
#       3 print(scada_long[["ts","plant_name","component_type","canonical_signal","value"]].head(5))
# ----> 5 save_parquet(scada_long, str(paths.stage_dir / "scada_long.parquet"))
#
# File C:\00_Developement\pv-fleet-health\src\pv_fleet_health\io.py:29, in save_parquet(df, path)
#      27 def save_parquet(df: pd.DataFrame, path: str) -> None:
#      28     os.makedirs(os.path.dirname(path), exist_ok=True)
# ---> 29     df.to_parquet(path, index=False)
#
# File c:\Users\User\miniconda3\envs\pv-fleet-health\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\User\miniconda3\envs\pv-fleet-health\Lib\site-packages\pandas\core\frame.py:3124, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3043 """
#    3044 Write a DataFrame to the binary parquet format.
#    3045
#    (...)   3120 >>> content = f.read()
#    3121 """
#    3122 from pandas.io.parquet import to_parquet
# -> 3124 return to_parquet(
#    3125     self,
#    3126     path,
#    3127     engine,
#    3128     compression=compression,
#    3129     index=index,
#    3130     partition_cols=partition_cols,
#    3131     storage_options=storage_options,
#    3132     **kwargs,
#    3133 )
#
# File c:\Users\User\miniconda3\envs\pv-fleet-health\Lib\site-packages\pandas\io\parquet.py:482, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     478 impl = get_engine(engine)
#     480 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 482 impl.write(
#     483     df,
#     484     path_or_buf,
#     485     compression=compression,
#     486     index=index,
#     487     partition_cols=partition_cols,
#     488     storage_options=storage_options,
#     489     filesystem=filesystem,
#     490     **kwargs,
#     491 )
#     493 if path is None:
#     494     assert isinstance(path_or_buf, io.BytesIO)
#
# File c:\Users\User\miniconda3\envs\pv-fleet-health\Lib\site-packages\pandas\io\parquet.py:191, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     188 if index is not None:
#     189     from_pandas_kwargs["preserve_index"] = index
# --> 191 table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
#     193 if df.attrs:
#     194     df_metadata = {"PANDAS_ATTRS": json.dumps(df.attrs)}
#
# File c:\Users\User\miniconda3\envs\pv-fleet-health\Lib\site-packages\pyarrow\table.pxi:4795, in pyarrow.lib.Table.from_pandas()
#
# File c:\Users\User\miniconda3\envs\pv-fleet-health\Lib\site-packages\pyarrow\pandas_compat.py:653, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     651     for i, maybe_fut in enumerate(arrays):
#     652         if isinstance(maybe_fut, futures.Future):
# --> 653             arrays[i] = maybe_fut.result()
#     655 types = [x.type for x in arrays]
#     657 if schema is None:
#
# File c:\Users\User\miniconda3\envs\pv-fleet-health\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\User\miniconda3\envs\pv-fleet-health\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\User\miniconda3\envs\pv-fleet-health\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\User\miniconda3\envs\pv-fleet-health\Lib\site-packages\pyarrow\pandas_compat.py:628, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     623 except (pa.ArrowInvalid,
#     624         pa.ArrowNotImplementedError,
#     625         pa.ArrowTypeError) as e:
#     626     e.args += (
#     627         f"Conversion failed for column {col.name} with type {col.dtype}",)
# --> 628     raise e
#     629 if not field_nullable and result.null_count > 0:
#     630     raise ValueError(f"Field {field} was non-nullable but pandas column "
#     631                      f"had {result.null_count} null values")
#
# File c:\Users\User\miniconda3\envs\pv-fleet-health\Lib\site-packages\pyarrow\pandas_compat.py:622, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     619     type_ = field.type
#     621 try:
# --> 622     result = pa.array(col, type=type_, from_pandas=True, safe=safe)
#     623 except (pa.ArrowInvalid,
#     624         pa.ArrowNotImplementedError,
#     625         pa.ArrowTypeError) as e:
#     626     e.args += (
#     627         f"Conversion failed for column {col.name} with type {col.dtype}",)
#
# File c:\Users\User\miniconda3\envs\pv-fleet-health\Lib\site-packages\pyarrow\array.pxi:365, in pyarrow.lib.array()
#
# File c:\Users\User\miniconda3\envs\pv-fleet-health\Lib\site-packages\pyarrow\array.pxi:91, in pyarrow.lib._ndarray_to_array()
#
# File c:\Users\User\miniconda3\envs\pv-fleet-health\Lib\site-packages\pyarrow\error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowTypeError: ("Expected bytes, got a 'float' object", 'Conversion failed for column value with type object')

# %%
save_parquet(scada_long, str(paths.stage_dir / "scada_long.parquet"))
print("Successfully saved scada_long.parquet")
# Out:
# Data types in scada_long:
# ts                  datetime64[ns, Europe/Athens]
# raw_column_name                            object
# value                                      object
# plant_name                                 object
# component_type                             object
# component_id                               object
# canonical_signal                           object
# unit                                       object
# mapped                                       bool
# unit_ok                                      bool
# expected_unit                              object
# dtype: object
#
# Value column info:
# object
# value
# <class 'str'>         431993
# <class 'float'>       141600
# <class 'NoneType'>      9607
# Name: count, dtype: int64
#
# Non-numeric values sample:
# Found 431993 non-numeric values
#                        plant_name       canonical_signal         value
# 0  Solar Concept 3721 KWp Lexaina  ac_frequency_error_hz   -1,88999999
# 1  Solar Concept 3721 KWp Lexaina  ac_frequency_error_hz  -0,643333316
# 2  Solar Concept 3721 KWp Lexaina  ac_frequency_error_hz   -1,43444443
# 3  Solar Concept 3721 KWp Lexaina  ac_frequency_error_hz   0,094444446
# 4  Solar Concept 3721 KWp Lexaina  ac_frequency_error_hz   -2,10777783
# 5  Solar Concept 3721 KWp Lexaina  ac_frequency_error_hz   -1,20666671
# 6  Solar Concept 3721 KWp Lexaina  ac_frequency_error_hz  -0,331111103
# 7  Solar Concept 3721 KWp Lexaina  ac_frequency_error_hz   0,241111115
# 8  Solar Concept 3721 KWp Lexaina  ac_frequency_error_hz   -2,79888892
# 9  Solar Concept 3721 KWp Lexaina  ac_frequency_error_hz  -0,402222216
#
# After conversion:
# float64
# Successfully saved scada_long.parquet
