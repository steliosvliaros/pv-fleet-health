# %%
import sys, numpy as np, pandas as pd
import matplotlib.pyplot as plt

print("python:", sys.version.split()[0])
print("numpy:", np.__version__)
print("pandas:", pd.__version__)

df = pd.DataFrame({"x": range(5), "y": [0, 1, 4, 9, 16]})
display(df)

plt.plot(df["x"], df["y"])
plt.show()
# Out:
# python: 3.11.14
# numpy: 2.4.0
# pandas: 2.3.3
#    x   y
# 0  0   0
# 1  1   1
# 2  2   4
# 3  3   9
# 4  4  16
